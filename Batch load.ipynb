# %%
# %sql
-- Insert new order
INSERT INTO datamodeling.source.source_data VALUES 
(
    1004,
    '2024-07-02',
    4,
    'David Wilson',
    'david@gmail.com',
    504,
    'Samsung Galaxy S24',
    'Electronics',
    1,
    899.99,
    'PayPal',
    'UK',
    '2024-07-02',
    current_timestamp()
);

# %%
# %sql
-- Update existing order
UPDATE datamodeling.source.source_data
SET
    quantity = 2,
    last_updated = '2024-07-02',
    ingestion_ts = current_timestamp()
WHERE order_id = 1001;
