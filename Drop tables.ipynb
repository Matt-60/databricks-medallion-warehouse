# %%
# %sql
DROP TABLE IF EXISTS datamodeling.source.source_data

# %%
# %sql
drop table datamodeling.bronze.bronze_table

# %%
# %sql
drop table if exists datamodeling.silver.silver_table

# %%
# %sql
drop table if exists datamodeling.gold.DimCustomers

# %%
# %sql
drop table if exists datamodeling.gold.DimProducts

# %%
# %sql
drop table if exists datamodeling.gold.DimPayments

# %%
# %sql
drop table if exists datamodeling.gold.DimRegion

# %%
# %sql
DROP TABLE IF EXISTS datamodeling.gold.fact_sales
